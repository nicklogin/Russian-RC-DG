# %%
import nltk

import evaluate
import json
import pandas as pd
import torch as tt

# %%
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to /home/user/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from ast import literal_eval
from datasets import load_dataset, Dataset
from nltk.tokenize import sent_tokenize
from math import ceil

# %%
from typing import Any, Dict
from tqdm import tqdm_notebook

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
from transformers import DataCollatorForSeq2Seq, Seq2SeqTrainer, Seq2SeqTrainingArguments
from transformers import PreTrainedModel, PreTrainedTokenizer

# %%
# models:
tokenizer = AutoTokenizer.from_pretrained("ai-forever/rugpt3small_based_on_gpt2")
model = AutoModelForCausalLM.from_pretrained("RuGPT3-MuSeRC-DG/checkpoint-57940").to(tt.device("cuda:0"))
tokenizer.pad_token = tokenizer.eos_token

# metrics:
bleu4 = evaluate.load("bleu")
sbleu = evaluate.load("sacrebleu")
rouge = evaluate.load("rouge")
meteor = evaluate.load("meteor")
# Out:
# [nltk_data] Downloading package wordnet to /home/user/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /home/user/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/user/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
df_ege = pd.read_excel("../race-ru-tf/EgeEvalDataset.xlsx", index_col="index")

# %%
df_ege.head()
# Out:
#                                             reading_text  \
# index
# 0       На задворках нашего села стояло на сваях длин...
# 1       Мы ехали берегом Лены на юг, а зима догоняла ...
# 2       Воспалённое состояние Поли, а главное, её сби...
# 3       Все мы любили «классного», хотя нельзя сказат...
# 4       В суровые военные годы во время бомбёжки моя ...
#
#                                           question  \
# index
# 0      Какое высказывание НЕ СООТВЕТСТВУЕТ тексту?
# 1      Какое высказывание НЕ СООТВЕТСТВУЕТ тексту?
# 2         Какое высказывание СООТВЕТСТВУЕТ тексту?
# 3      Какое высказывание НЕ СООТВЕТСТВУЕТ тексту?
# 4      Какое высказывание НЕ СООТВЕТСТВУЕТ тексту?
#
#                                             right_answer  \
# index
# 0       Полонез вызвал у автора желание заплакать и с...
# 1       Подобравшись ближе к берегу, козы бросились к...
# 2                   Автор письма хранит подарок девочки.
# 3       Ребята сразу невзлюбили своего классного руко...
# 4       Бабушка рассказчицы долгое время работала в т...
#
#                                              distractors
# index
# 0      [' Рассказчик был сиротой.', ' В детстве эта м...
# 1      [' Собеседник рассказчика, Сокольский, сомнева...
# 2      [' Родион встретил девочку перед наступлением....
# 3      [' Белый билет не давал учителю возможности уй...
# 4      [' Убежище, в котором укрывалась рассказчица, ...

# %%
df_ege["distractors"] = df_ege["distractors"].apply(literal_eval)

# %%
df_zero_ = df_ege["distractors"][df_ege["distractors"].apply(len) == 0]

# %%
df_zero_
# Out:
# Series([], Name: distractors, dtype: object)

# %%
MAX_LEN = 69

# %%
ege_dataset = Dataset.from_pandas(df_ege)

# %%
def to_dg_format(dataset: list[dict[str, Any]]) -> list[dict[str, Any]]:
    dataset_processed = []
    item_id = 0

    for item in dataset:
        new_item = {
            "item_id": item["index"],
            "passage": item["reading_text"],
            "question": item["question"],
            "distractors": item["distractors"],
            "right_answer": item["right_answer"]
        }
        dataset_processed.append(new_item)

    return dataset_processed

LB = "\n  "

def to_dg_format_final(dataset: list[dict[str, Any]]) -> list[dict[str, Any]]:
    new_dataset = []

    for item in dataset:
        new_item = {
            "item_id": item["item_id"],
            "inp": f'{item["passage"]} ВОПРОС: {item["question"]} ПРАВИЛЬНЫЙ ОТВЕТ: {item["right_answer"]} НЕПРАВИЛЬНЫЕ ВАРИАНТЫ ОТВЕТА:',
            "outp_expected": f'{item["passage"]} ВОПРОС: {item["question"]} ПРАВИЛЬНЫЙ ОТВЕТ: {item["right_answer"]} НЕПРАВИЛЬНЫЕ ВАРИАНТЫ ОТВЕТА:{LB + LB.join(item["distractors"])}',
            "right_answer": item["right_answer"],
            "distractors": LB + LB.join(item["distractors"])
        }
        new_dataset.append(new_item)

    return new_dataset

# %%
ege_dataset = Dataset.from_list(to_dg_format_final(to_dg_format(ege_dataset)))

# %%
MAX_LEN = 69 # 0.99 quantile from MuSeRC train dataset

# %%
def cut_last_break(input_: list[str]) -> list[str]:
    output = [s[:s.rfind('\n')] for s in input_]
    return output

def parse_options(input_: list[str]) -> list[str]:
    output = [s.strip() for s in input_]
    output = [set(option.strip() for option in s.split('\n')) for s in output]
    output = [sorted(list(s))[:3] for s in output]
    output = ['\n'.join(s) for s in output]
    return output

def get_metric_inputs(
    input_batch: list[str], label_batch: list[str],
    model: PreTrainedModel, tokenizer: PreTrainedTokenizer
) -> list[str]:
    FACTOR = 1.1

    input_batch_ = tokenizer(input_batch, return_tensors="pt", padding=True)["input_ids"].to(tt.device("cuda:0"))
    label_batch_ = tokenizer(label_batch, return_tensors="pt", padding=True)["input_ids"]

    input_length = input_batch_.shape[-1]
    output_length = label_batch_.shape[-1]
    
    with tt.no_grad():
        output_batch = model.generate(input_batch_, max_length=input_length + ceil(output_length * FACTOR))
        output_batch = output_batch[:,input_length:]

    output = tokenizer.batch_decode(output_batch)
    del input_batch_
    del output_batch
    del label_batch_
    tt.cuda.empty_cache()

    output = cut_last_break(output)
    output = parse_options(output)

    return output

def compute_metrics(output: list[str], label_batch: list[str]) -> dict[str, Any]:
    metric_dict = {
        "bleu": bleu4.compute(predictions=output, references=[[label] for label in label_batch]),
        "sbleu": sbleu.compute(predictions=output, references=[[label] for label in label_batch]),
        "rouge": rouge.compute(predictions=output, references=label_batch),
        "meteor": meteor.compute(predictions=output, references=label_batch)
    }
    return metric_dict

def compute_metrics_on_dataset(
    dataset: Dataset, model: PreTrainedModel=model,
    tokenizer: PreTrainedTokenizer=tokenizer
) -> pd.DataFrame:
    batch_size = 1

    n_steps = (len(dataset) // batch_size) + 1
    metrics = []

    for i in tqdm_notebook(range(n_steps), total=n_steps):
        slice = dataset[i*batch_size:(i+1)*batch_size]
        if slice["inp"]:
            distractors = slice["distractors"]
            
            output = get_metric_inputs(slice["inp"], distractors, model, tokenizer)

            distractors = parse_options(distractors)
    
            if len(distractors[0]) > 0:
                metric = compute_metrics(output, distractors)
                metrics.append({
                    "item_id": slice["item_id"][0],
                    "inp": slice["inp"][0],
                    "distractors": distractors[0],
                    
                    "output": output[0],
        
                    "bleu": metric["bleu"]["bleu"],
                    "sbleu": metric["sbleu"]["score"],
                    "rouge1": metric["rouge"]["rouge1"],
                    "rouge2": metric["rouge"]["rouge2"],
                    "rougeL": metric["rouge"]["rougeL"],
                    "rougeLsum": metric["rouge"]["rougeLsum"],
                    "meteor": metric["meteor"]["meteor"],
                })

    return pd.DataFrame(metrics)

METRIC_COLS = [
    "bleu", "sbleu", "rouge1", "rouge2",
    "rougeL", "rougeLsum", "meteor"
]

# %%
metrics_ege = compute_metrics_on_dataset(ege_dataset)

# %%
metrics_ege

# %%
metrics_ege.to_csv("metrics_muserc_ege_gpt3.csv", sep=';')

# %%
metrics_ege[METRIC_COLS].describe()
# Out:
#        bleu      sbleu  rouge1  rouge2  rougeL  rougeLsum     meteor
# count  55.0  55.000000    55.0    55.0    55.0       55.0  55.000000
# mean    0.0   1.353994     0.0     0.0     0.0        0.0   0.066506
# std     0.0   1.144720     0.0     0.0     0.0        0.0   0.030049
# min     0.0   0.008291     0.0     0.0     0.0        0.0   0.014409
# 25%     0.0   0.812118     0.0     0.0     0.0        0.0   0.049138
# 50%     0.0   1.265449     0.0     0.0     0.0        0.0   0.065147
# 75%     0.0   1.601997     0.0     0.0     0.0        0.0   0.077272
# max     0.0   8.562365     0.0     0.0     0.0        0.0   0.195789

# %%
metrics_ege[METRIC_COLS].describe()
# Out:
#        bleu      sbleu  rouge1  rouge2  rougeL  rougeLsum     meteor
# count  55.0  55.000000    55.0    55.0    55.0       55.0  55.000000
# mean    0.0   1.353994     0.0     0.0     0.0        0.0   0.066506
# std     0.0   1.144720     0.0     0.0     0.0        0.0   0.030049
# min     0.0   0.008291     0.0     0.0     0.0        0.0   0.014409
# 25%     0.0   0.812118     0.0     0.0     0.0        0.0   0.049138
# 50%     0.0   1.265449     0.0     0.0     0.0        0.0   0.065147
# 75%     0.0   1.601997     0.0     0.0     0.0        0.0   0.077272
# max     0.0   8.562365     0.0     0.0     0.0        0.0   0.195789

# %%
len(metrics_ege)
# Out:
# 55

# %%
metrics_ege
# Out:
#     item_id                                                inp  \
# 0         0   На задворках нашего села стояло на сваях длин...
# 1         1   Мы ехали берегом Лены на юг, а зима догоняла ...
# 2         2   Воспалённое состояние Поли, а главное, её сби...
# 3         3   Все мы любили «классного», хотя нельзя сказат...
# 4         4   В суровые военные годы во время бомбёжки моя ...
# 5         6   В те отдалённые прежние времена приблизительн...
# 6         7   Когда Скоков пришёл к полному, тысячу раз про...
# 7         8   Два камня У самого берега лежали два камня − ...
# 8         9   В те отдалённые прежние времена приблизительн...
# 9        10   Эти трое были живые, смешливые, острые на язы...
# 10       11   Немецкие миномёты били по всей равнине, взмет...
# 11       12   3емля — космическое тело, а мы — космонавты, ...
# 12       13   — Мне в Борисоглебский переулок, — сообщила я...
# 13       14   Иногда к дяде Коле приходил в гости сельский ...
# 14       15   Василий Конаков, или просто Вася, как звали м...
# 15       16   Шли большие военные учения, и мы, моряки, тож...
# 16       17   Какое же зеркало жизни наш язык! Нет, он поис...
# 17       18   Развитие науки не раз ставило перед учёными в...
# 18       20   Я знала замечательную писательницу. Её звали ...
# 19       21   Я видел это на пригородной танцплощадке. Весё...
# 20       23   На седьмой странице был некролог: « Тимоти Са...
# 21       24   Вопрос «Кто виноват?» называют чисто русским ...
# 22       25   Жил однажды чудак… Он был очень богат и имел ...
# 23       26   Для меня ясно одно: главные участники истории...
# 24       27   Русский характер! Поди-ка опиши его... Расска...
# 25       28   – Здесь полюс, поздравляю вас, ребята! – имен...
# 26       29   Оставляя пока в стороне все материальные выго...
# 27       30   Когда-то один древний китайский философ сказа...
# 28       31   Когда при Берге произносили слово «Родина», о...
# 29       32   Недавно прочитал в интервью городского чиновн...
# 30       33   Сергей Николаевич Плетёнкин вернулся домой, к...
# 31       34  Прочитайте текст и выполните задание. Прибыв н...
# 32       35   Небо заволокло злыми тучами, дождь печально к...
# 33       36   В былые годы, когда я был помоложе, я имел не...
# 34       37   Есть животные, которые не могут слышать, и их...
# 35       38   Я стояла в ординаторской, смотрела на фикус и...
# 36       39   Пляж был пуст. Друзья прошли на самый край мо...
# 37       40   Москва поглощает огромное количество цветов, ...
# 38       41   Без сомнения, старость – это ступень нашей жи...
# 39       42   Художественное творчество, с моей точки зрени...
# 40       44   Не знаю, кто из великих сказал, что более все...
# 41       45   В конце жизни Гёте сказал: «Добрые люди не зн...
# 42       46  — Учился я плохо и никогда этого себе не прощу...
# 43       47   Я получил недавно письмо, в котором школьница...
# 44       48   Как художник создаёт пейзажную картину, так и...
# 45       49   Надобно сказать, что у нас на Руси если не уг...
# 46       50   Моё детство прошло в глухой ангарской деревне...
# 47       52   Было мне тогда всего девять лет от роду. Как-...
# 48       54   Москва не есть обыкновенный большой город, ка...
# 49       55   Многие считают понятие чести устарелым, несов...
# 50       57   Шла война, на которую мы, шестнадцатилетние м...
# 51       58   Однажды Архимед сел в ванну и вдруг почувство...
# 52       59   В маленьком городишке Стратфорде на маленькой...
# 53      103   …Мы недавно поженились. Ещё ходили по улице и...
# 54      151   Прутский поход Петра Первого, предпринятый в ...
#
#                                           distractors  \
# 0   В детстве эта мелодия вызывала другие чувства....
# 1   По мнению рассказчика, животных спас не только...
# 2   Варя читала письмо много раз.\nРодион встретил...
# 3   Белый билет не давал учителю возможности уйти ...
# 4   Подростки нуждаются в поддержке со стороны взр...
# 5   Духовное благополучие в мире не достигнуто.\nН...
# 6   Герой повествования был готов активно бороться...
# 7   Кремень не зазнался, а на самом деле привык жи...
# 8   Духовное благополучие в мире не достигнуто.\nН...
# 9   В Эрмитаж некоторые ходят лишь ради того, чтоб...
# 10  Командир и товарищи отговаривали связиста, реш...
# 11  Жизнедеятельность человека представляет реальн...
# 12  Рассказчица выяснила, кто была та девушка возл...
# 13  В дом к родственникам рассказчика приходил сел...
# 14  В пятой роте, которой командовал Конаков, было...
# 15  Рассказчик был родом из деревни, поэтому он та...
# 16  В средствах массовой информации часто поднимае...
# 17  Развитие науки тесно связано с развитием этики...
# 18  В жизни много испытаний, и проявление мужества...
# 19  Девушка поняла, с какой целью её пригласил тан...
# 20  Герой-рассказчик действительно много лет назад...
# 21  Вопрос «Кто виноват?»называют чисто русским во...
# 22  Если человечество не задумается о смысле жизни...
# 23  3а долгие четыре года войны герои не утратили ...
# 24  В госпитале Егору Дрёмову не смогли полностью ...
# 25  История не помнит всех, кто совершал открытия....
# 26  Многие при изучении наук преследуют только одн...
# 27  Дерево не может делать ошибок.\nЖизнь рассказч...
# 28  В попытках найти стиль своего времени Берг пре...
# 29  Для того чтобы стать высокообразованным челове...
# 30  В семье героя царил мир и полное взаимопониман...
# 31  Александр Зеленин— молодой врач, которого напр...
# 32  Поликарп Семёнович убежден, что помочь людям о...
# 33  Глядя на бродяг, мы нередко испытываем чувство...
# 34  Автор не согласен с мыслью о том, что патриоти...
# 35  После разговора с Чагиным в его кабинете Кира ...
# 36  Алексей Максимов в глубине души недолюбливал с...
# 37  Люди готовы платить за цветы немалые деньги.\n...
# 38  В старости люди, имея за плечами богатый жизне...
# 39  Можно рисовать где угодно и чем угодно: истинн...
# 40  Многие люди совершают благородные поступки не ...
# 41  Любовь к чтению иногда начинается с чтения пер...
# 42  Искусство способно объединить людей.\nРодной я...
# 43  Друг героя-рассказчика признался ему в совершё...
# 44  Внешний вид страны, лицо страны должны быть пр...
# 45  На Руси обращение к человеку зависело от его с...
# 46  В деревне, где родился рассказчик, все были бе...
# 47  В момент встречи с Мареем герою, от лица котор...
# 48  «Согласный гимн колоколов» златоглавых церквей...
# 49  Антон Чехов в знак протеста отказался от звани...
# 50  Мишкин отец доставал продукты, так как работал...
# 51  Каждый раз, когда Архимед садился в ванну, он ...
# 52  Англичане сохранили дом Шекспира в память о ве...
# 53  Героине повествования медсёстры не разрешали в...
# 54  Великий визирь решил вступить в сражение с рус...
#
#                                                output  bleu     sbleu  rouge1  \
# 0   "Земля не даёт ему умереть."\n"Песню."\n"Прост...   0.0  2.263301     0.0
# 1   "Да, заметили. " (2) А ещё как-то раз поглядел...   0.0  0.626713     0.0
# 2   "Что Поле не трус, но живет в России."\n"Что н...   0.0  2.075274     0.0
# 3    "В новой группе."\n"В новой компании."\n"Домой."   0.0  1.428237     0.0
# 4   "Бабушка уехала к родному отцу."\n"Костя любит...   0.0  1.574021     0.0
# 5   "Оно не может не видеть всеобщего блага."\n"Он...   0.0  1.550944     0.0
# 6   "Заполнить бюджет."\n"Заполнить пробелы в бюдж...   0.0  1.295757     0.0
# 7   "Всегда относился к природе как к развлечению....   0.0  1.219062     0.0
# 8   "Человечество не ценит того, что ему дается."\...   0.0  1.611668     0.0
# 9   "Он должен стремиться к счастью."\n"Счастье - ...   0.0  1.654380     0.0
# 10  "Командир вызывал его на связь."\n"Командир не...   0.0  0.742004     0.0
# 11  "Оно не может стать достоянием технологической...   0.0  1.767312     0.0
# 12  "Да кто его не читал."\n"Девушку с седеющей го...   0.0  0.864285     0.0
# 13  "Что Толстой не читал Чехова."\n"Что автор не ...   0.0  1.192356     0.0
# 14  "Вася должен был бы научиться стрелять из авто...   0.0  1.308725     0.0
# 15  "Тогда, когда нечего будет есть."\n"Тогда, ког...   0.0  1.168579     0.0
# 16  "В прилагательном честь."\n"В слове честь."\n"...   0.0  1.470443     0.0
# 17  "Давно прозвучали эти слова."\n"Они рассматрив...   0.0  1.509386     0.0
# 18  "Я не боюсь взрослых."\n"Я не боюсь врачей."\n...   0.0  0.292490     0.0
# 19  "В молодости я считал себя человеком отлично в...   0.0  1.579046     0.0
# 20  "За потерянное время."\n"За свою жизнь."\n"За ...   0.0  0.207616     0.0
# 21  "Человечество не ценит того, что ему есть."\n"...   0.0  1.190942     0.0
# 22  "К сожалению, я не знаю этого."\n"Кризис."\n"О...   0.0  2.338018     0.0
# 23  " солнце может не взойти утром, потому что его...   0.0  1.592326     0.0
# 24  "Да, Егор Дрёмов не был ни добрым, ни ласковым...   0.0  1.417633     0.0
# 25  "Оно не нашел своего счастья."\n"Оно не смог в...   0.0  1.966306     0.0
# 26  "Если человек не занимался ранее, он может уме...   0.0  1.734991     0.0
# 27  "Дерево не может вынести вида "деревня"."\n"Де...   0.0  8.562365     0.0
# 28  "Земля отцов не моя Родина."\n"Когда Берг полу...   0.0  0.628874     0.0
# 29  "Их можно вымуштровать, обучив немногим актёрс...   0.0  0.744652     0.0
# 30  "Когда я был в командировке, мне вспомнилось д...   0.0  1.958225     0.0
# 31             "О несправедливости."\n"Оба философа."   0.0  0.008291     0.0
# 32  "Он равнодушен к смерти."\n"Пространство вокру...   0.0  0.794075     0.0
# 33  "Не верю в бога."\nНет ничего приятнее жить в ...   0.0  1.128885     0.0
# 34  "Они в ужасе."\n"Они не видят и не слышат, жив...   0.0  1.074623     0.0
# 35  "Как главный герой матча."\n"Как художник карт...   0.0  0.181907     0.0
# 36  "Магия."\n"О несправедливости."\n"Природа не л...   0.0  0.248190     0.0
# 37  "Оно не так уж и дорого."\n"Пятьсот тысяч долл...   0.0  2.226430     0.0
# 38  "Можно быть одиноким и плыть по жизни в поиска...   0.0  1.790499     0.0
# 39  "Лео не смог вынести вида картинок."\n"Лео, в ...   0.0  0.595043     0.0
# 40  "Что не любит просить милостыню."\n"Что не хот...   0.0  0.858674     0.0
# 41  "Читатель должен видеть в тексте свою любовь."...   0.0  1.212935     0.0
# 42  "Не умеет варить варенье из сливы."\n"Не умеет...   0.0  2.167132     0.0
# 43            "Игра случая."\n"Кризис."\n"Лермонтов."   0.0  0.346795     0.0
# 44  "Думаем о прочности сооружений."\n"О земле."\n...   0.0  1.279007     0.0
# 45  "Иван Петрович всегда смеётся."\n"Орел и не см...   0.0  1.374927     0.0
# 46  "Вася жил в 5-м доме и получил по наследству а...   0.0  1.030989     0.0
# 47  "Что дыма без дыма."\n"Что на небе видели слиш...   0.0  1.190942     0.0
# 48   "Бессмертный полк."\n"Крестовый поход."\n"Лувр."   0.0  0.776446     0.0
# 49  "Честь - это дуэль."\n"Честь это доброта."\n"Ч...   0.0  1.444350     0.0
# 50  "Что не было войны."\n"Что не было голодного м...   0.0  1.180356     0.0
# 51  "Бесчисленная коллекция стеклянных фигурок."\n...   0.0  0.248190     0.0
# 52  "Да, есть люди, которые любят кушать в столово...   0.0  1.679426     0.0
# 53  "Боль может превратиться в ликование."\n"Любит...   0.0  0.830161     0.0
# 54  "Казалось, что все погибли, кроме Петра."\n"Ко...   0.0  1.265449     0.0
#
#     rouge2  rougeL  rougeLsum    meteor
# 0      0.0     0.0        0.0  0.069444
# 1      0.0     0.0        0.0  0.039062
# 2      0.0     0.0        0.0  0.111111
# 3      0.0     0.0        0.0  0.072202
# 4      0.0     0.0        0.0  0.053571
# 5      0.0     0.0        0.0  0.075758
# 6      0.0     0.0        0.0  0.058962
# 7      0.0     0.0        0.0  0.076419
# 8      0.0     0.0        0.0  0.074850
# 9      0.0     0.0        0.0  0.081967
# 10     0.0     0.0        0.0  0.056497
# 11     0.0     0.0        0.0  0.104167
# 12     0.0     0.0        0.0  0.068966
# 13     0.0     0.0        0.0  0.051813
# 14     0.0     0.0        0.0  0.042735
# 15     0.0     0.0        0.0  0.050505
# 16     0.0     0.0        0.0  0.071429
# 17     0.0     0.0        0.0  0.047771
# 18     0.0     0.0        0.0  0.036284
# 19     0.0     0.0        0.0  0.089928
# 20     0.0     0.0        0.0  0.024155
# 21     0.0     0.0        0.0  0.050891
# 22     0.0     0.0        0.0  0.116883
# 23     0.0     0.0        0.0  0.121951
# 24     0.0     0.0        0.0  0.117468
# 25     0.0     0.0        0.0  0.074627
# 26     0.0     0.0        0.0  0.078864
# 27     0.0     0.0        0.0  0.195789
# 28     0.0     0.0        0.0  0.064103
# 29     0.0     0.0        0.0  0.056306
# 30     0.0     0.0        0.0  0.065217
# 31     0.0     0.0        0.0  0.014409
# 32     0.0     0.0        0.0  0.037783
# 33     0.0     0.0        0.0  0.041096
# 34     0.0     0.0        0.0  0.068027
# 35     0.0     0.0        0.0  0.030817
# 36     0.0     0.0        0.0  0.028355
# 37     0.0     0.0        0.0  0.084388
# 38     0.0     0.0        0.0  0.100464
# 39     0.0     0.0        0.0  0.067340
# 40     0.0     0.0        0.0  0.046838
# 41     0.0     0.0        0.0  0.069767
# 42     0.0     0.0        0.0  0.065217
# 43     0.0     0.0        0.0  0.035885
# 44     0.0     0.0        0.0  0.059701
# 45     0.0     0.0        0.0  0.056391
# 46     0.0     0.0        0.0  0.078125
# 47     0.0     0.0        0.0  0.053333
# 48     0.0     0.0        0.0  0.042135
# 49     0.0     0.0        0.0  0.065147
# 50     0.0     0.0        0.0  0.054945
# 51     0.0     0.0        0.0  0.028355
# 52     0.0     0.0        0.0  0.080128
# 53     0.0     0.0        0.0  0.053763
# 54     0.0     0.0        0.0  0.095694

# %%
len(df_ege)
# Out:
# 55

# %%
df_ege["distractors"].apply(len).sum()
# Out:
# 166
